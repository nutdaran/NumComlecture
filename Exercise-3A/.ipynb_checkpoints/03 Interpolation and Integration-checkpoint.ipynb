# %% [markdown]
# # Interpolation
# -> guessing  value between data point

# %% [markdown]
# - 2 points -> line -> mx+c
# - 3 points -> parabola -> $ax^2+bx+c$
# - 4 points -> polynomial degree 3 -> $ax^3+bx^2+cx+d$

# %% [markdown]
# # Lagrange Interpolation Polynomial

# %% [markdown]
# n points -> polynomial deg n-1

# %% [markdown]
# - pass through every point perfectly

# %% [markdown]
# ## Example

# %% [markdown]
# ![Screen%20Shot%202565-01-27%20at%2012.44.31.png](attachment:Screen%20Shot%202565-01-27%20at%2012.44.31.png)
#
# $w_1(x) = (x-3)(x-4)(x-7)/(1-3)(1-4)(1-7)$
# $w_2(x) = (x-1)(x-4)(x-7)/(3-1)(3-4)(3-7)$
# $w_3(x) = (x-1)(x-3)(x-7)/(4-1)(4-3)(4-7)$
# $w_4(x) = (x-1)(x-3)(x-4)/(7-1)(7-3)(7-4)$
# #### final form:
# $2w_1(x) + w_2(x) + 0.5w_3(x) + 1.5w_4(x)$

# %% [markdown]
# # Numerical Integration
# ![Screen%20Shot%202565-01-27%20at%2014.12.09.png](attachment:Screen%20Shot%202565-01-27%20at%2014.12.09.png)
#
# - area under the curve -> sum of trapezoids
# - anti derivative
#
# ### area of Trapezoid
# height1 = $f(x_i)$
# height2 = $f(x_{i+1})$
# length = $x_{i+1} - x_i$

# %% [markdown]
# ![Screen%20Shot%202565-01-27%20at%2014.20.28.png](attachment:Screen%20Shot%202565-01-27%20at%2014.20.28.png)

# %% [markdown]
# ## Integral formula
# ![Screen%20Shot%202565-01-27%20at%2014.32.59.png](attachment:Screen%20Shot%202565-01-27%20at%2014.32.59.png)

# %% [markdown]
# ## Exercise Interpolation

# %%
# %matplotlib inline
import math
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# 1) Plot these four points (2,3), (3,1), (4,2), (5,2).

# %%
# higher order function/Functor/Closure(React,Vlaue,etc.)
# (float) -> [(float) -> float]
xs = np.array([2.,3,4,5])
ys = np.array([3.,1,2,2])
plt.plot(xs,ys,'o')
plt.grid()

# %%
def w_factory(xs, i):
    def w(x):
        numerator = np.prod([ x-a for j, a in enumerate(xs) if i!=j ])
        denominator = np.prod([ xs[i]-a for j, a in enumerate(xs) if i!=j ])
        return numerator / denominator
    return w

w0 = w_factory(xs, 0) # -> polynomial that is 0 everywhere except at x[0]
print(w0(2), w0(3), w0(4), w0(5))
# Out:
# 1.0 -0.0 0.0 -0.0

# %%
def lagrange_factory(xs, ys): # polynomial that pass through every xs,ys
    def lagrange(x):
        ws = [w_factory(xs, i) for i, _ in enumerate(xs)]
        return np.sum(y*ws[i](x) for i, y in enumerate(ys))
    return lagrange

lg = lagrange_factory(xs, ys)
plt.plot(xs, ys, 'o')
plt.grid()
xxs = np.linspace(1, 6, 100)
plt.plot(xxs, [lg(x) for x in xxs])
# Out:
# /var/folders/jw/dvcl0gln5c747h52sxl00y_h0000gn/T/ipykernel_26612/492102180.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return np.sum(y*ws[i](x) for i, y in enumerate(ys))

# %%
justin = f(3.14) #x #justin is (float) -> (float)

justin(4.) #y
# Out:
# 7.140000000000001

# %% [markdown]
# 2) Find the polynomial of degree 3 that pass through these four points. Plot to verify.

# %%
justin(1.23)
# Out:
# 4.37

# %% [markdown]
# 3) Find polynomial of degree 3 that pass through these four points. Plot to verify.
#
# (1,2) (2,0) (3,2) (7,1)

# %% [markdown]
# 4) Write a function `ledendre(x)` which compute the legendre polynomial given the list of x values in xs and y values in ys.
#
# `legendre(1.5)`
#
# should have the same value as the polymial you found in 3) evaluated at x=1.5.
#
# For those of you who know functional programming try write a functor that return a polynomial.

# %% [markdown]
# 5) Now sample 11 points  from $f(x) = \sin(x)$ for for $x\in[0, \pi]$. Plot $\sin(x)$ along with those 11 points. Make sure your $\sin(x)$ is plotted with more than 100 points

# %%
xs = np.linspace(0,np.pi,100)
ys = np.sin(xs)
plt.plot(xs,ys)

samples = np.linspace(0,np.pi,11)
y_samples = np.sin(samples)
plt.plot(samples,y_samples,'o')

lg = lagrange_factory(samples,y_samples)
plt.plot(xs,[lg(x) for x in xs])
# Out:
# /var/folders/jw/dvcl0gln5c747h52sxl00y_h0000gn/T/ipykernel_26612/492102180.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return np.sum(y*ws[i](x) for i, y in enumerate(ys))

# %% [markdown]
# 6) Plot legendre polynomial for these points. How similar is it to $\sin(x)$ function. Make sure your legendre is plotte with at least 100 points.

# %% [markdown]
# 7) Now sample 11 points  from $f(x) = \sin(200x)$ for for $x\in[0, \pi]$. Plot $\sin(200*x)$ along with those 11 points. Note the 200. Then plot legendre polynomial for these points.

# %%
xs = np.linspace(0,np.pi, 10000)
ys = np.sin(200*xs)
plt.plot(xs,ys)

samples = np.linspace(0, np.pi, 11)
y_samples = np.sin(200*samples)
plt.plot(samples, y_samples, 'o')


lg = lagrange_factory(samples, y_samples)
plt.plot(xs, [lg(x) for x in xs])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/jw/dvcl0gln5c747h52sxl00y_h0000gn/T/ipykernel_34589/1656946636.py in <module>
#       8
#       9
# ---> 10 lg = lagrange_factory(samples, y_samples)
#      11 plt.plot(xs, [lg(x) for x in xs])
#
# NameError: name 'lagrange_factory' is not defined

# %% [markdown]
# 8) Does it pass through all the point? Does it look like the original function?

# %% [markdown]
# ## Exercise Integration

# %% [markdown]
# 0) What is $$ \int \limits_{x=1}^{x=3} x^3 \; dx $$

# %%
3**4/4 - 1/4
# Out:
# 20.0

# %%
def f(x):
    return x**3

def trapezoid(f,l,r,n):
    dx = (r-l)/n
    return 0.5*dx*(f(l) + 2*sum(f(l+i*dx) for i in range(l,n)) + f(r))

# %% [markdown]
# 1)Use Trapezoid Rule to calculate
#
# $$ \int \limits_{x=1}^{x=3} x^3 \; dx $$
#
# Using 1 piece.

# %% [markdown]
# 2)Use Trapezoid Rule to calculate
#
# $$ \int \limits_{x=1}^{x=3} x^3 \; dx $$
#
# Using 100 pieces.

# %%
trapezoid(f,1,3,10)
# Out:
# 20.080000000000002

# %%
trapezoid(f,1,3,100)
# Out:
# 20.0008

# %%
trapezoid(f,1,3,1000)
# Out:
# 20.00000800000001

# %% [markdown]
# 3) What is the bound on error for 1)?

# %%
3**4/4 - 1/4
# Out:
# 20.0

# %% [markdown]
# 4) What is the bound on error for 2)?

# %% [markdown]
# 5) Compute the following integral
# $$ \int \limits_{x=0}^{x=1} e^{-x} \sin(x^2) \; dx $$
#
# using 100 sub divisions. This is one of those integral you can't do by hands.

# %%
def f(x):
    return np.exp(-x)*np.sin(x**2)

trapezoid(f,0,1,100)
# Out:
# 0.15091330026867264

# %%
from scipy.integrate import quad

quad(f,0,1)
# Out:
# (0.1509125672227444, 1.6754660683598256e-15)

# %% [markdown]
# 6) If we want compute
# $$ \int \limits_{x=0}^{x=1} e^{-x} \; dx $$
# that is at most $10^{-6}$ away from the real answer. How many subdivisions do we need?

# %% [markdown]
# 7) Compute the integral above and make sure your answer is at most $10^{-6}$ away from the real answer.
