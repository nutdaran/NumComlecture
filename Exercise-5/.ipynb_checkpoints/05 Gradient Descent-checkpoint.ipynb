# %%
# %matplotlib inline
import numpy as np
import math
from matplotlib import pyplot as plt

# %% [markdown]
# # Optimization
# find tuhe value of x such that the value f(x) is minimized called **"argmin f(x)"**
# <br>
# f(x) -> value f(x) that minimize f(x)
# ![Screen%20Shot%202565-02-10%20at%2012.06.48.png](attachment:Screen%20Shot%202565-02-10%20at%2012.06.48.png)

# %% [markdown]
# if we want to solve this: **sin(x)=x**, we turn this equation to **argmin f(x) = argmin sin(x)=x**<p>
# $argmin$ $sin(x)-x = 0$<br>
#     $(sin(x)-x)^2$ #make it positive

# %% [markdown]
# # Linear Regression
# - find the lim that "fit" the point

# %% [markdown]
# ### 1D problem
# ![Screen%20Shot%202565-02-10%20at%2012.24.07.png](attachment:Screen%20Shot%202565-02-10%20at%2012.24.07.png)

# %% [markdown]
# if slope is negative -> right -> more x<br>
# if slope is positve -> left -> less x

# %% [markdown]
# ## 1D Gradient Descent

# %% [markdown]
# 1) Let us consider the function
# $$ f(x) = (x-2)^2 + 1 $$
# First plot it.

# %% [markdown]
# 2) If we start at $x=4$, which way should we move and why?

# %% [markdown]
# 3)If the step size is constants = 1.1, what does the update rule look like?
#
# $$x_{n+1} = \ldots$$

# %% [markdown]
# 4)Let try it with step size = 1.1. For 10 iteration. Print and plot your point as you go. Can you understand the behavior?

# %%
def optimize(f,fp,x0,step_size,n):
    guess = x0
    guesses = [guess]
    for i in range(n):
        guess = guess - fp(guess)/abs(fp(guess))*step_size
        guesses.append(guess)
    return guess,np.array(guesses)

def f(x):
    return (x-2)**2+1

def fp(x):
    return 2*(x-2)

xs = np.linspace(0,5,100)
ys = f(xs)
plt.plot(xs,ys)

x,guesses= optimize(f,fp,x0=4,step_size=1.1,n=10)
plt.plot(guesses,f(guesses),'o-')
print(guesses)
# Out:
# [4.  2.9 1.8 2.9 1.8 2.9 1.8 2.9 1.8 2.9 1.8]

# %% [markdown]
# 5)Now let's try step size=0.01 for 100 iteration. Print and plot your point as you go. Can you understand the behavior?

# %%
xs = np.linspace(0,5,100)
ys = f(xs)
plt.plot(xs,ys)

x,guesses= optimize(f,fp,x0=4,step_size=0.01,n=100)
plt.plot(guesses,f(guesses),'o-')
guesses
# Out:
# array([4.  , 3.99, 3.98, 3.97, 3.96, 3.95, 3.94, 3.93, 3.92, 3.91, 3.9 ,
#        3.89, 3.88, 3.87, 3.86, 3.85, 3.84, 3.83, 3.82, 3.81, 3.8 , 3.79,
#        3.78, 3.77, 3.76, 3.75, 3.74, 3.73, 3.72, 3.71, 3.7 , 3.69, 3.68,
#        3.67, 3.66, 3.65, 3.64, 3.63, 3.62, 3.61, 3.6 , 3.59, 3.58, 3.57,
#        3.56, 3.55, 3.54, 3.53, 3.52, 3.51, 3.5 , 3.49, 3.48, 3.47, 3.46,
#        3.45, 3.44, 3.43, 3.42, 3.41, 3.4 , 3.39, 3.38, 3.37, 3.36, 3.35,
#        3.34, 3.33, 3.32, 3.31, 3.3 , 3.29, 3.28, 3.27, 3.26, 3.25, 3.24,
#        3.23, 3.22, 3.21, 3.2 , 3.19, 3.18, 3.17, 3.16, 3.15, 3.14, 3.13,
#        3.12, 3.11, 3.1 , 3.09, 3.08, 3.07, 3.06, 3.05, 3.04, 3.03, 3.02,
#        3.01, 3.  ])

# %% [markdown]
# 6) When do we want the step size to be small and when do you want the step size to be big?

# %%
# big --> fast , not accurate
# small --> slow , accurate

## want accurate and fast

# Big when are far away from solution (slope is big)
# Small when we are closer to the solution (slope is small)

step_size --- propotion to the |slope|
x = x - direction * step_size

# %% [markdown]
# ![Screen%20Shot%202565-02-10%20at%2012.56.10.png](attachment:Screen%20Shot%202565-02-10%20at%2012.56.10.png)
# Big -> big step<br>
# Small -> small step

# %% [markdown]
# 7) What function kind of does that?

# %%
def grad_dsec_ld(fp,x0,learning_rate,n):
    guess = x0
    guesses = [guess]
    for i in range(n):
        guess = guess - fp(guess)*learning_rate
        guesses.append(guess)
    return guess,np.array(guesses)

xs = np.linspace(0,5,100)
ys = f(xs)
plt.plot(xs,ys)

x,guesses = grad_dsec_ld(fp,-4,learning_rate=0.1,n=10)
plt.plot(guesses,f(guesses),"o-")
print(guesses)

#Big learning rate --> Big step --> fast & furious(if it works, it's fast)
#Small learning rate --> small step
# Out:
# [-4.         -2.8        -1.84       -1.072      -0.4576      0.03392
#   0.427136    0.7417088   0.99336704  1.19469363  1.35575491]

# %% [markdown]
# $f(x_m+h) = f(x_m)+h*f'(x_m)+h^2/2*f''(x_m)$ #f'(x_m)=0<br>
# $f(x+h) = f(x_m)+h^2/2f''(x_m)$

# %% [markdown]
# $\sum x^4 = ax^5+bx^4+cs^3+dx^2+ex+f$<br>
# $=poly$ $of$ $deg5$

# %% [markdown]
# 8)If we use that function, what does the update rule looks like.

# %% [markdown]
# 9) Try it with $\lambda=0.1$. Print and Plot to see what happens?

# %% [markdown]
# 10) Try it with $\lambda = 1.1$. For 4 iterations. Can you see how it goes?

# %% [markdown]
# ### Multi-Dimension Gradient Descent

# %% [markdown]
# 1) Let us consider the function.
# $$f(x,y) = (x-2)^2 + xy + y^2 + 1$$
# Make the 3D plot.

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
#see matplotlib3d surface
def f(x,y):
    return (x-2)**2+x*y+y**2+1
nx = 200
ny = 200
x = np.linspace(-20,20,nx)
y = np.linspace(-20,20,ny)
xgrid, ygrid = np.meshgrid(x, y)
#print ygrid
uz = np.zeros((nx,ny))
for ix in range(nx):
    for iy in range(ny):
        xx = x[ix]
        yy = y[iy]
        uz[iy,ix] = f(xx,yy) ##<<<<<<This is not a typo: [iy,ix]
        
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
plt.gca().view_init(elev=15., azim=30)
ucs = ax.plot_surface(xgrid, ygrid, uz, cmap=cm.coolwarm)
plt.title('f(x,y)')
# Out:
# Text(0.5, 0.92, 'f(x,y)')

# %% [markdown]
# 2) Plot the contour.

# %%
from matplotlib import cm
#see http://matplotlib.org/examples/pylab_examples/contour_demo.html
def f(x,y):
    return (x-2)**2+x*y+y**2+1

nx = 200
ny = 200
x = np.linspace(-20,20,nx)
y = np.linspace(-20,20,ny)
xgrid, ygrid = np.meshgrid(x, y)
#print ygrid
uz = np.zeros((nx,ny))

for ix in range(nx):
    for iy in range(ny):
        xx = x[ix]
        yy = y[iy]
        uz[iy,ix] = f(xxyy) ##<<<<<<This is not a typo: [iy,ix]

ucs = plt.contour(x, y, uz, [2,10,50,100,200,400,500], cmap=cm.brg)
plt.clabel(ucs, inline=1, fontsize=10)
plt.grid()
plt.title('f(x,y)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/jw/dvcl0gln5c747h52sxl00y_h0000gn/T/ipykernel_18661/2946758163.py in <module>
#      16         xx = x[ix]
#      17         yy = y[iy]
# ---> 18         uz[iy,ix] = f(xxyy) ##<<<<<<This is not a typo: [iy,ix]
#      19
#      20 ucs = plt.contour(x, y, uz, [2,10,50,100,200,400,500], cmap=cm.brg)
#
# NameError: name 'xxyy' is not defined

# %% [markdown]
# ## Gradient Descent (n-D)
# $$f(x_n+\Delta x)=f(x_n)+f'(x_n)*\Delta x$$<br>
# $f'(x_n)*\Delta x$ <- as negative as possible<br>
# taylor's series:
# $f(x_n+\Delta x,y_n+\Delta y)=f(x_n,y_n)+(\frac{\partial f}{\partial x} *\Delta x +\frac{\partial f}{\partial y} *\Delta y)$<br>
# ![Screen%20Shot%202565-02-10%20at%2014.01.47.png](attachment:Screen%20Shot%202565-02-10%20at%2014.01.47.png)
# ### Gradient Descent formula = $\bar x_n+1 = \bar x_n - \lambda \bar\nabla f(x_n)$

# %% [markdown]
# 3)Where do you think the minimum is?

# %% [markdown]
# 4)What is the gradient at (10,-15)? Use plt.arrow to plot arrow.

# %% [markdown]
# 5) If we want to minimize the function which way should we go? Find the unit vector in that direction.

# %% [markdown]
# 6) What should your update rule look like? Use vector addition.

# %%
def grad(f, v, h=0.01):
    #[df/dx, df/dy, ...]
    # df/dx --> (f(v+[h, 0]) - f(v))/h
    # df/dy --> (f(v+[0, h]) - f(v))/h
    n_var = len(v)
    ret = np.zeros(n_var)
    for i in range(n_var):
        dv = np.zeros(n_var)
        dv[i] = h
        diff = (f(v + dv) - f(v - dv))/2/h
        ret[i] = diff
    return ret
    
def f(v):
    x, y = v
    return x**2 + 2*y**2

grad(f, [1.,2.])
    
def grad_desc(f, v0, learning_rate, n):
    v = np.array(v0) # copy and ensure numpy
    vs = [v]
    for i in range(n):
        v = v - learning_rate*grad(f, v)
        vs.append(v)
    return v, vs

def f(v):
    x, y = v
    return (x-2)**2  + x*y + y**2 + 1


v, vs = grad_desc(f, [10., -15.], 0.1, n=200)

print(v)
#print(vs)
for x, y in vs:
    plt.plot(x, y, 'o')

nx = 200
ny = 200
x = np.linspace(-20,20,nx)
y = np.linspace(-20,20,ny)
xgrid, ygrid = np.meshgrid(x, y)
#print ygrid
uz = np.zeros((nx,ny))

for ix in range(nx):
    for iy in range(ny):
        xx = x[ix]
        yy = y[iy]
        uz[iy,ix] = f([xx,yy]) ##<<<<<<This is not a typo: [iy,ix]

ucs = plt.contour(x, y, uz, [2,10,50,100,200,400,500], cmap=cm.brg)
plt.clabel(ucs, inline=1, fontsize=10)
plt.grid()
plt.title('f(x,y)')
# Out:
# [ 2.66666667 -1.33333334]
# Text(0.5, 1.0, 'f(x,y)')

# %% [markdown]
# $$f(x,y)=(x-2)^2+xy+y^2+1$$

# %% [markdown]
# 7) Use what we learn in 1D. How far should we go? What should the update rule really look like?

# %% [markdown]
# 8) Use $\lambda = 0.1$ and see where the points go

# %% [markdown]
# ### Linear Regression Revisited

# %% [markdown]
# Let us consider the problem of findind a line that pass through the points.

# %%
np.random.seed(123)
n = 100
dx = np.linspace(0,1,n)
dy = -2*dx + 1 + np.random.randn(n)/2
plt.plot(dx,dy,'.r')

# %% [markdown]
# 1) What exactly are we trying to minimize and why?

# %%
def f(v):
    m, c = v
    # good line --> near the points --> give me a low value
    # gad line --> far from the point --> give me a high value
    return sum((m*dx + c - dy)**2) # require some thinking # sum ( mx[i] + c -y[i] )**2

# %% [markdown]
# 2) Minimize and Visualize it.

# %%
v, _ = grad_desc(f, [0., 1.], learning_rate=0.001, n=10000)
m, c = v
print(m, c)
xs = np.linspace(0,1, 100)
plt.plot(dx, dy, 'o')
plt.plot(xs, m*xs + c)
# Out:
# -1.9859661699936841 1.0065376217420168

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from scipy.optimize import minimize
res = minimize(f, [0., 1.])
print(res.x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/jw/dvcl0gln5c747h52sxl00y_h0000gn/T/ipykernel_18661/2063639619.py in <module>
#       1 from scipy.optimize import minimize
# ----> 2 res = minimize(f, [0., 1.])
#       3 print(res.x)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     616         return _minimize_cg(fun, x0, args, jac, callback, **options)
#     617     elif meth == 'bfgs':
# --> 618         return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     619     elif meth == 'newton-cg':
#     620         return _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, **unknown_options)
#    1199         maxiter = len(x0) * 200
#    1200
# -> 1201     sf = _prepare_scalar_function(fun, x0, jac, args=args, epsilon=eps,
#    1202                                   finite_diff_rel_step=finite_diff_rel_step)
#    1203
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/optimize.py in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     259     # ScalarFunction caches. Reuse of fun(x) during grad
#     260     # calculation reduces overall function evaluations.
# --> 261     sf = ScalarFunction(fun, x0, args, grad, hess,
#     262                         finite_diff_rel_step, bounds, epsilon=epsilon)
#     263
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in __init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     138
#     139         self._update_fun_impl = update_fun
# --> 140         self._update_fun()
#     141
#     142         # Gradient evaluation
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     231     def _update_fun(self):
#     232         if not self.f_updated:
# --> 233             self._update_fun_impl()
#     234             self.f_updated = True
#     235
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     135
#     136         def update_fun():
# --> 137             self.f = fun_wrapped(self.x)
#     138
#     139         self._update_fun_impl = update_fun
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     132             # Overwriting results in undefined behaviour because
#     133             # fun(self.x) will change self.x, with the two no longer linked.
# --> 134             return fun(np.copy(x), *args)
#     135
#     136         def update_fun():
#
# /var/folders/jw/dvcl0gln5c747h52sxl00y_h0000gn/T/ipykernel_18661/4237268530.py in f(v)
#       1 def f(v):
#       2     m,c = v
# ----> 3     for color, (x,y) in zip(c,d):
#       4         blue = color ==0
#       5         red = not blue
#
# TypeError: 'numpy.float64' object is not iterable

# %% [markdown]
# ### Separating Line.

# %% [markdown]
# We want to draw a separating line betwen two datasets shown below.

# %%
np.random.seed(234)
n1 = 100
n2 = 100
mean = [0, 0]
cov = [[1, -0.5], [-0.5, 1]]
r1, r2 = np.random.multivariate_normal(mean, cov, n1).T
#plt.plot(r1, r2, '.r')

mean = [2, 2]
cov = [[1, 0], [0, 1]]
b1, b2 = np.random.multivariate_normal(mean, cov, n2).T
#plt.plot(b1, b2, '.b')

c = np.zeros(n1+n2)
c[:n1] = 1.
c[n1:] = 0.
#print c

d = np.zeros((n1+n2,2))
d[:n1,0] = r1
d[:n1,1] = r2
d[n1:,0] = b1
d[n1:,1] = b2

# %%
plt.plot(d[c==1,0], d[c==1,1],'.r')#note boolean indexing
plt.plot(d[c==0,0], d[c==0,1],'.b')#note boolean indexing

# %% [markdown]
# 1) How can we model this as a optimization problem?

# %%
def f(v):
    m, b = v # c is used somewhere else
    cost = 0
    for color, (x, y) in zip(c, d):
        blue = color==0
        red = not blue
        dy = m*x + b - y
        above = dy > 0
        below = dy < 0
        if (red and above) or (blue and below):
            cost += abs(dy)
    return cost

res = minimize(f, [0., 1.])

# %%
m, b = res.x

plt.plot(d[c==1,0], d[c==1,1],'.r')#note boolean indexing
plt.plot(d[c==0,0], d[c==0,1],'.b')#note boolean indexing

xs = np.linspace(-2, 5, 100)
plt.plot(xs, m*xs + b)
